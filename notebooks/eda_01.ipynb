# %%
import pandas as pd
import numpy as np

# CMAPSS column names
cols = (
    ["unit", "cycle"] +
    [f"op_{i}" for i in range(1, 4)] +
    [f"s_{i}" for i in range(1, 22)]
)

df = pd.read_csv(
    "..\\data\\raw\\train_FD001.txt",
    sep=r"\s+",
    header=None,
    names=cols
)

df.head()
# Out:
#    unit  cycle    op_1    op_2   op_3     s_1     s_2      s_3      s_4  \
# 0     1      1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60
# 1     1      2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14
# 2     1      3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20
# 3     1      4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87
# 4     1      5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22
#
#      s_5  ...    s_12     s_13     s_14    s_15  s_16  s_17  s_18   s_19  \
# 0  14.62  ...  521.66  2388.02  8138.62  8.4195  0.03   392  2388  100.0
# 1  14.62  ...  522.28  2388.07  8131.49  8.4318  0.03   392  2388  100.0
# 2  14.62  ...  522.42  2388.03  8133.23  8.4178  0.03   390  2388  100.0
# 3  14.62  ...  522.86  2388.08  8133.83  8.3682  0.03   392  2388  100.0
# 4  14.62  ...  522.19  2388.04  8133.80  8.4294  0.03   393  2388  100.0
#
#     s_20     s_21
# 0  39.06  23.4190
# 1  39.00  23.4236
# 2  38.95  23.3442
# ...

# %% [markdown]
# ## what is cmapss?
# - cmapss is a high fidelity turbofan engine simulator developed by NASA for research in aircraft engine health monitoring and prognostics
# ## what is RUL (Remaining Useful Life)
# - RUL is the number of operating cycles left before an engine reaches failure
# ## what is final cycle evaluation?
# - in the test set engines are truncated before failure .
# - The model must predict RUL only at the **final observed cycle** of each engine . These predictions are compared against the true hidden RUL values.

# %%
# max cycle per engine
max_cycle = df.groupby('unit')['cycle'].max().reset_index()
max_cycle.columns = ['unit', 'max_cycle']
df = df.merge(max_cycle,on='unit')
df['RUL'] = df['max_cycle'] -  df['cycle'] 
df[['unit','cycle','RUL']].head()
# Out:
#    unit  cycle  RUL
# 0     1      1  191
# 1     1      2  190
# 2     1      3  189
# 3     1      4  188
# 4     1      5  187

# %% [markdown]
# ### why cap RUL ?
# in CMAPSS early cycle of an engine can have very large RUL values.
# capping RUL means limiting the maximum target value to a fixed threshold.
# ### what problem does it solve ?
# 1. **reduces target imbalances**
# without capping , many early - cycle samples dominate the dataset with large RUL values.
# 2. **Stabilizes Training**
# Large target increase variance and make regression harder to optimize
# 3. **Focuses on actionable regime**
# predicting on lower RUL is much more important then capping at Higher RUL eg 180 200+
#
# capping makes the model focus on the degradation region that matters most.

# %%
df["RUL"] = df["RUL"].clip(upper=140)

# %% [markdown]
# ## why engine wise ?
# RUL depends on the failure cycle of each **individual engine**.
# Since every engine fails at a different time, RUL must be computed seperately per engine trajectory.
#
# ## why not row wise ?
# row wise calculation ignores engine boundaries and mixes different trajectories.
# This would produce incorrect RUL values because rows from different engines do not share the same failure time.

# %%
from sklearn.model_selection import train_test_split
engine_ids = df['unit'].unique()
train_engine_ids , val_engine_ids = train_test_split(engine_ids,random_state=42,test_size=0.2)
train_set_df = df[df['unit'].isin(train_engine_ids)]
val_set_df = df[df['unit'].isin(val_engine_ids)]

# %% [markdown]
# ## why only s_ features?
# the S_features are sensor measurements that directly reflect the engine's physical condition.
# They contain the degradation information needed to predict RUL.
#
# ## why exclude cycle (for now)?
# the cycle number is just a time index not a physical measurement.
# including it can let the model rely on time progression instead of learning true degradation patterns.
# we exclude it to force the model to learn from sensor behaviour.

# %%
features = [c for c in df.columns if c.startswith("s_")]

X_train = train_set_df[features]
y_train = train_set_df["RUL"]

X_val = val_set_df[features]
y_val = val_set_df["RUL"]

# %% [markdown]
# ## why fit only on train?
# scaling parameters must be only computed from the training data so that the model learns using information available  during training.
# ## what leakage does this prevent?
# if we fit the scaler on validation set or test data, we use information from unseen data to compute scaling statistics.
# this leaks future information into training and leads to overly optimistic evaluation result.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score


model = LinearRegression()
model.fit(X_train, y_train)

y_preds_lr = model.predict(X_val)

mae = mean_absolute_error(y_val, y_preds_lr)
rmse = root_mean_squared_error(y_val, y_preds_lr)

r2 = r2_score(y_val,y_preds_lr)
print("r2:",r2)
print("MAE:", mae)
print(f"RMSE : {rmse}")
# Out:
# r2: 0.7480997951141044
# MAE: 18.824860250167937
# RMSE : 23.492424441771934

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,6))
plt.scatter(y_val,y_preds_lr,alpha=0.1,color='blue')
plt.plot([y_val.min(), y_val.max()],
         [y_val.min(), y_val.max()],
         'r--', lw=2)

plt.xlabel('actual rul')
plt.ylabel('predicted rul')
plt.title('linear regression')
plt.grid(True)

plt.show()

# %% [markdown]
# ## LInear regression Baseline
# **motivation** used as a simple baseline model to evaluate whether sensor features have predictive signal for RUL
# **assumption**
# - global linear relationship between sensor values and RUL
# - additive feature contributions
# - no nonlinear interaction
#
# **result**
# - MAE : 21.27
# - RMSE : 26.68
#
# **observation :**
# the model captures some degradation trend but shows relatively high error , suggesting that engine degradation may not folow a purely linear pattern

# %%
from sklearn.tree import DecisionTreeRegressor


model = DecisionTreeRegressor(max_depth=6)
model.fit(X_train, y_train)

y_preds_dr = model.predict(X_val)

mae = mean_absolute_error(y_val, y_preds_dr)
rmse = root_mean_squared_error(y_val, y_preds_dr)
r2 = r2_score(y_val,y_preds_dr)

print("r2:",r2)
print("MAE:", mae)
print(f"RMSE : {rmse}")
# Out:
# r2: 0.7578702397891489
# MAE: 17.418022962804677
# RMSE : 23.032318861027193

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,6))
plt.scatter(y_val,y_preds_dr,alpha=0.1,color='blue')
plt.plot([y_val.min(), y_val.max()],
         [y_val.min(), y_val.max()],
         'r--', lw=2)

plt.xlabel('actual rul')
plt.ylabel('predicted rul')
plt.title('decision tree')
plt.grid(True)

plt.show()

# %% [markdown]
# ## decision tree regressor (max depth = 6)
#
# **Motivation**
# to model non linear relationships and interaction between sensor measurements.
#
# **model choice:**
# - capture nonlinear degradation data
# - depth constrained to control overfitting
#
# **Results:**
# - MAE : 20.6
# - RMSE : 26.38
#
# **Observation:**
# slight improvement over linear regression, indicating that non linear modeling helps.
# depth constraint balances bias and variance , improving generalization to unseen engines.

# %%
from sklearn.ensemble import RandomForestRegressor
rand_for_model = RandomForestRegressor(max_depth=None,n_estimators=100,random_state=42)
rand_for_model.fit(X_train,y_train)
y_preds_fr = rand_for_model.predict(X_val)
mae = mean_absolute_error(y_val, y_preds_fr)
rmse = root_mean_squared_error(y_val, y_preds_fr)
r2 = r2_score(y_val,y_preds_fr)

print("r2:",r2)
print("MAE:", mae)
print(f"RMSE : {rmse}")
# Out:
# r2: 0.8115119958987418
# MAE: 15.233041769041769
# RMSE : 20.32148477569844

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,6))
plt.scatter(y_val,y_preds_fr,alpha=0.1,color='blue')
plt.plot([y_val.min(), y_val.max()],
         [y_val.min(), y_val.max()],
         'r--', lw=2)

plt.xlabel('actual rul')
plt.ylabel('predicted rul')
plt.title('random forest')
plt.grid(True)

plt.show()

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(
    n_estimators=300,
    learning_rate=0.07,
    max_depth=3,
    random_state=42
)

gbr.fit(X_train, y_train)
y_preds_gbr = gbr.predict(X_val)

mae = mean_absolute_error(y_val, y_preds_gbr)
rmse = root_mean_squared_error(y_val, y_preds_gbr)
r2 = r2_score(y_val, y_preds_gbr)


print("R2:", r2)
print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# R2: 0.8139868097817853
# MAE: 15.151342058882667
# RMSE: 20.187635233122993

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,6))
plt.scatter(y_val,y_preds_gbr,alpha=0.6,color='blue')
plt.plot([y_val.min(), y_val.max()],
         [y_val.min(), y_val.max()],
         'r--', lw=2)

plt.xlabel('actual rul')
plt.ylabel('predicted rul')
plt.title('random forest')
plt.grid(True)

plt.show()

# %%
residuals = {
    "Linear Regression": y_val - y_preds_lr,
    "Decision Tree": y_val - y_preds_dr,
    "Random Forest": y_val - y_preds_fr,
    "Gradient Boosting": y_val - y_preds_gbr
}
residuals
# Out:
# {'Linear Regression': 0         9.634318
#  1        12.918703
#  2         5.471656
#  3        -6.502409
#  4        13.469984
#             ...
#  18510   -19.981249
#  18511    -9.872025
#  18512    -3.080375
#  18513     0.150317
#  18514    -0.156036
#  Name: RUL, Length: 4070, dtype: float64,
#  'Decision Tree': 0        17.955945
#  1        17.955945
#  2        10.230252
#  3         4.585261
#  4        10.230252
#             ...
#  18510    -4.256944
#  18511    -5.256944
#  18512    -6.256944
#  18513    -3.191882
#  18514    -4.191882
#  Name: RUL, Length: 4070, dtype: float64,
#  'Random Forest': 0        12.18
#  1        12.21
#  2         3.93
#  3         8.80
#  4         7.12
#           ...
#  18510    -6.33
#  18511    -1.74
#  18512    -2.04
#  18513    -0.58
#  18514    -1.83
#  Name: RUL, Length: 4070, dtype: float64,
#  'Gradient Boosting': 0        8.825888
#  1        9.041256
#  2        6.830296
#  3        5.523788
#  4        9.417865
# ...

# %%
import matplotlib.pyplot as plt

for model_name, res in residuals.items():
    plt.figure()
    plt.scatter(y_val, res, alpha=0.2)
    plt.axhline(0)   # perfect prediction line
    plt.xlabel("True RUL")
    plt.ylabel("Residual (y_true - y_pred)")
    plt.title(f"Residual Plot - {model_name}")
    plt.show()

# %% [markdown]
# ## Residual Analysis
#
# Residual analysis is performed to understand model error behavior beyond traditional metrics such as MAE or RMSE.
#
# Residuals are defined as:
#
# Residual = y_true - y_pred
#
# - Positive residual → Underestimation of RUL (safer)
# - Negative residual → Overestimation of RUL (riskier)
#
# ---
#
# ### Residual vs True RUL
#
# Residual plots are used to evaluate model performance across different stages of engine life.
#
# **Key observations:**
#
# - Residual spread increases at higher RUL values, indicating that early-life prediction is more uncertain.
# - Linear Regression shows a curved pattern, suggesting systematic bias and poor ability to capture nonlinear degradation.
# - Decision Tree produces striped residual patterns due to discrete prediction outputs, indicating high variance.
# - Random Forest reduces variance and produces smoother residual distribution.
# - Gradient Boosting shows the most balanced and tightly clustered residuals, suggesting improved bias correction.
#
# ---
#
# ### Low RUL Safety Consideration
#
# The low RUL region is critical because prediction errors near failure can create safety risks. Ensemble models, particularly Gradient Boosting, show more stable and balanced error behavior in this region compared to simpler models.
#
# ---
#
# ### Dataset Note
#
# A vertical concentration of points near maximum RUL is observed due to dataset RUL clipping and does not indicate model error.
#
# ---
#
# ### Summary
#
# Residual analysis indicates that ensemble-based methods outperform individual models in both stability and safety of RUL prediction.

# %%
low_rul_threshold = 20
low_rul_mask = y_val < low_rul_threshold

results = []

for model_name, res in residuals.items():
    
    res_low = res[low_rul_mask]
    y_true_low = y_val[low_rul_mask]
    
    mean_residual = np.mean(res_low)
    overestimation = np.sum(res_low < 0) / len(res_low) * 100
    max_overestimation = np.min(res_low)
    
    results.append([
        model_name,
        mean_residual,
        overestimation,
        max_overestimation
    ])

df_results = pd.DataFrame(results, columns=[
    "Model",
    "Mean Residual (Low RUL)",
    "% Overestimation",
    "Max Overestimation"
])

print(df_results)
# Out:
#                Model  Mean Residual (Low RUL)  % Overestimation  \
# 0  Linear Regression                -2.688585             59.75
# 1      Decision Tree                -5.068156             75.50
# 2      Random Forest                -3.255225             78.75
# 3  Gradient Boosting                -2.585154             70.25
#
#    Max Overestimation
# 0          -41.258633
# 1          -64.705357
# 2          -25.880000
# 3          -25.687758

# %%
for model_name, res in residuals.items():
    plt.figure()
    plt.hist(res[low_rul_mask], bins=30)
    plt.title(f"Residual Distribution (Low RUL) - {model_name}")
    plt.xlabel("Residual")
    plt.show()

# %%
def safety_mae(y_true, y_pred):
    residual = y_true - y_pred
    abs_error = np.abs(residual)
    
    # Apply asymmetric penalty
    safety_error = np.where(residual < 0, 2 * abs_error, abs_error)
    
    return np.mean(safety_error)

# Compute Safety-MAE for each model
safety_results = {
    "Linear Regression": safety_mae(y_val, y_preds_lr),
    "Decision Tree": safety_mae(y_val, y_preds_dr),
    "Random Forest": safety_mae(y_val, y_preds_fr),
    "Gradient Boosting": safety_mae(y_val, y_preds_gbr)
}

# Convert to DataFrame for easy comparison
df_safety = pd.DataFrame(
    list(safety_results.items()),
    columns=["Model", "Safety-MAE"]
).sort_values("Safety-MAE")

df_safety
# Out:
#                Model  Safety-MAE
# 3  Gradient Boosting   22.608727
# 2      Random Forest   22.708700
# 1      Decision Tree   26.254659
# 0  Linear Regression   28.258486

# %%
from sklearn.metrics import mean_absolute_error

mae_results = {
    "Linear Regression": mean_absolute_error(y_val, y_preds_lr),
    "Decision Tree": mean_absolute_error(y_val, y_preds_dr),
    "Random Forest": mean_absolute_error(y_val, y_preds_fr),
    "Gradient Boosting": mean_absolute_error(y_val, y_preds_gbr)
}

df_mae = pd.DataFrame(
    list(mae_results.items()),
    columns=["Model", "MAE"]
)

# Merge comparison
df_compare = df_mae.merge(df_safety, on="Model")
df_compare = df_compare.sort_values("Safety-MAE")

df_compare
# Out:
#                Model        MAE  Safety-MAE
# 3  Gradient Boosting  15.151342   22.608727
# 2      Random Forest  15.233042   22.708700
# 1      Decision Tree  17.418023   26.254659
# 0  Linear Regression  18.824860   28.258486

# %% [markdown]
# ### Safety-MAE Results Interpretation
#
# Safety-MAE was computed to evaluate model performance under asymmetric error penalization, where overestimation errors are penalized more heavily than underestimation errors.
#
# #### Ranking Comparison
#
# Model ranking remained consistent between MAE and Safety-MAE:
#
# 1. Gradient Boosting
# 2. Random Forest
# 3. Decision Tree
# 4. Linear Regression
#
# This indicates that the models with higher overall accuracy also demonstrate safer prediction behavior.
#
# ---
#
# #### Safety Penalty Analysis
#
# All models experienced an increase in error under Safety-MAE evaluation. However, ensemble-based models showed smaller penalty increases compared to simpler models.
#
# - Gradient Boosting demonstrated the lowest Safety-MAE, indicating strong balance between accuracy and safety.
# - Random Forest showed similar behavior with slightly higher penalty.
# - Decision Tree exhibited higher penalty increase, suggesting unstable predictions and higher overestimation risk.
# - Linear Regression showed the largest penalty increase, indicating frequent overestimation of RUL.
#
# ---
#
# #### Key Insight
#
# The consistent ranking between MAE and Safety-MAE suggests that ensemble models not only improve prediction accuracy but also provide safer prognostic behavior near failure conditions.
#
# ---
#
# #### Conclusion
#
# Gradient Boosting is identified as the most reliable model, providing the best combination of predictive accuracy and safety-oriented performance.

# %%
import numpy as np

def risk_loss(y_true, y_pred, lambda_, gamma):
    r = y_true - y_pred
    maintenance = np.maximum(r, 0)
    catastrophic = lambda_ * np.exp(-gamma * y_true) * np.maximum(-r, 0)
    return np.mean(maintenance + catastrophic)

# %%
lambda_values = [1, 2, 3, 5]
gamma_values = [0.01, 0.05, 0.1]
models = {
    "LinearRegression": y_preds_lr,
    "DecisionTree": y_preds_dr,
    "RandomForest": y_preds_fr,
    "GradientBoosting": y_preds_gbr
}

# %%
for lambda_ in lambda_values:
    for gamma in gamma_values:
        print(f"\nLambda = {lambda_}, Gamma = {gamma}")
        print("-" * 40)
        
        results = {}
        for model_name, y_pred in models.items():
            results[model_name] = risk_loss(y_val, y_pred, lambda_, gamma)
        
        # Sort by loss
        sorted_results = sorted(results.items(), key=lambda x: x[1])
        
        for model_name, loss in sorted_results:
            print(f"{model_name}: {loss:.4f}")
# Out:
# Lambda = 1, Gamma = 0.01
# ----------------------------------------
# GradientBoosting: 11.6687
# RandomForest: 11.7767
# DecisionTree: 13.4158
# LinearRegression: 14.7860
#
# Lambda = 1, Gamma = 0.05
# ----------------------------------------
# GradientBoosting: 8.3384
# RandomForest: 8.4353
# DecisionTree: 9.4741
# LinearRegression: 10.6153
#
# Lambda = 1, Gamma = 0.1
# ----------------------------------------
# GradientBoosting: 7.9044
# RandomForest: 7.9807
# DecisionTree: 8.9144
# LinearRegression: 9.8355
#
# Lambda = 2, Gamma = 0.01
# ----------------------------------------
# GradientBoosting: 15.6434
# RandomForest: 15.7960
# DecisionTree: 18.2502
# LinearRegression: 20.1808
#
# Lambda = 2, Gamma = 0.05
# ----------------------------------------
# GradientBoosting: 8.9828
# RandomForest: 9.1133
# DecisionTree: 10.3668
# LinearRegression: 11.8394
#
# Lambda = 2, Gamma = 0.1
# ----------------------------------------
# GradientBoosting: 8.1149
# RandomForest: 8.2040
# ...

# %% [markdown]
# ## Sensitivity Analysis: Risk-Aware Loss (λ, γ)
#
# We evaluated the proposed exponential risk-aware loss across:
#
# - λ ∈ {1, 2, 3, 5}
# - γ ∈ {0.01, 0.05, 0.1}
#
# ### Key Observations
#
# 1. **Model ranking remained stable** across all λ and γ combinations:
#    - Gradient Boosting consistently achieved the lowest risk loss.
#    - Random Forest ranked second.
#    - Decision Tree and Linear Regression followed.
#
# 2. **Effect of increasing λ (catastrophic weight):**
#    - Risk loss increased significantly when γ was small (e.g., γ = 0.01).
#    - This indicates that with low γ, catastrophic penalties apply broadly across the RUL range.
#    - Larger λ amplifies global asymmetry toward penalizing overestimation.
#
# 3. **Effect of increasing γ (proximity sensitivity):**
#    - As γ increased, overall risk loss decreased.
#    - This suggests that catastrophic penalties became localized near very low RUL values.
#    - High γ reduces the influence of catastrophic weighting away from failure.
#
# ### Interpretation
#
# For the CMAPSS dataset and evaluated models:
#
# - MAE-based ranking aligns with safety-aware exponential loss ranking.
# - The best statistical model (Gradient Boosting) is also the safest under exponential catastrophic weighting.
#
# This suggests robustness of model ranking under asymmetric, proximity-aware cost structures.

# %%
def count_dangerous_overestimates(y_true, y_pred, threshold):
    r = y_true - y_pred
    
    # Near failure region
    near_failure = y_true < threshold
    
    # Overestimation condition
    overestimate = r < 0
    
    # Dangerous cases
    dangerous = near_failure & overestimate
    
    return np.sum(dangerous)

# %%
thresholds = [20, 10, 5]
for threshold in thresholds:
    print(f"\nOverestimations when RUL < {threshold}")
    print("-" * 40)
    
    for model_name, y_pred in models.items():
        count = count_dangerous_overestimates(y_val, y_pred, threshold)
        print(f"{model_name}: {count}")
# Out:
# Overestimations when RUL < 20
# ----------------------------------------
# LinearRegression: 239
# DecisionTree: 302
# RandomForest: 315
# GradientBoosting: 281
#
# Overestimations when RUL < 10
# ----------------------------------------
# LinearRegression: 101
# DecisionTree: 180
# RandomForest: 177
# GradientBoosting: 163
#
# Overestimations when RUL < 5
# ----------------------------------------
# LinearRegression: 43
# DecisionTree: 100
# RandomForest: 96
# GradientBoosting: 89

# %% [markdown]
# ## Catastrophic Overestimation Analysis (Low RUL Region)
#
# We evaluated the number of overestimations (predicted RUL > true RUL) in critical low-RUL regions.
#
# ### Overestimations when RUL < 20
# - Linear Regression: 307
# - Decision Tree: 307
# - Random Forest: 318
# - Gradient Boosting: 302
#
# Differences are minor in this broader near-failure region.
#
# ---
#
# ### Overestimations when RUL < 10
# - Linear Regression: 125
# - Decision Tree: 169
# - Random Forest: 168
# - Gradient Boosting: 168
#
# Linear Regression exhibits significantly fewer dangerous overestimations.
#
# ---
#
# ### Overestimations when RUL < 5
# - Linear Regression: 52
# - Decision Tree: 100
# - Random Forest: 96
# - Gradient Boosting: 96
#
# In the extreme failure region, Linear Regression makes approximately half the number of overestimations compared to tree-based models.
#
# ---
#
# ### Interpretation
#
# Although Gradient Boosting achieves the lowest MAE and lowest exponential risk loss overall,
# Linear Regression demonstrates more conservative behavior in the most critical RUL region (RUL < 5).
#
# This suggests:
#
# - Tree-based models improve global predictive accuracy.
# - However, they may produce more aggressive overestimations very close to failure.
# - Simple linear models may exhibit inherently conservative behavior near extreme degradation.
#
# Therefore, average risk metrics alone may not fully capture safety-critical behavior in extreme low-RUL regimes.

# %%
def avg_overestimate_magnitude(y_true, y_pred, threshold):
    r = y_true - y_pred
    
    # mask for dangerous region
    mask = (y_true < threshold) & (r < 0)
    
    if np.sum(mask) == 0:
        return 0.0
    
    # magnitude of overestimation = predicted - true = -r
    return np.mean(-r[mask])

# %%
thresholds = [20, 10, 5]

for threshold in thresholds:
    print(f"\nAverage overestimation magnitude when RUL < {threshold}")
    print("-" * 50)
    
    for model_name, y_pred in models.items():
        magnitude = avg_overestimate_magnitude(y_val, y_pred, threshold)
        print(f"{model_name}: {magnitude:.4f}")
# Out:
# Average overestimation magnitude when RUL < 20
# --------------------------------------------------
# LinearRegression: 15.1081
# DecisionTree: 7.7929
# RandomForest: 4.8769
# GradientBoosting: 4.8907
#
# Average overestimation magnitude when RUL < 10
# --------------------------------------------------
# LinearRegression: 11.2624
# DecisionTree: 6.0909
# RandomForest: 3.6454
# GradientBoosting: 3.9409
#
# Average overestimation magnitude when RUL < 5
# --------------------------------------------------
# LinearRegression: 10.0447
# DecisionTree: 5.8089
# RandomForest: 3.3401
# GradientBoosting: 3.7929

# %% [markdown]
# ## Severity Analysis of Overestimation in Low-RUL Regions
#
# We analyzed not only the frequency of overestimations, but also their average magnitude.
#
# ### RUL < 5 (Extreme Failure Region)
#
# Frequency:
# - Linear Regression: 52
# - Decision Tree: 100
# - Random Forest: 96
# - Gradient Boosting: 96
#
# Average Magnitude:
# - Linear Regression: 8.03
# - Decision Tree: 5.95
# - Random Forest: 4.85
# - Gradient Boosting: 4.38
#
# ### Interpretation
#
# Linear Regression produces fewer overestimations near extreme failure,
# but when it overestimates, the magnitude is significantly larger.
#
# Tree-based models (especially Gradient Boosting):
#
# - Produce more frequent overestimations,
# - But with substantially smaller magnitudes.
#
# This reveals a critical safety tradeoff:
#
# - Linear Regression → rare but severe overestimation errors.
# - Gradient Boosting → more frequent but mild overestimations.
#
# The exponential risk-aware loss favors Gradient Boosting because
# it penalizes large overestimations more heavily near failure.
#
# Thus, although Linear Regression appears conservative by frequency,
# its larger magnitude errors make it riskier under proximity-weighted catastrophic cost.

# %%
def catastrophic_risk_index(y_true, y_pred, threshold):
    r = y_true - y_pred
    
    mask_region = y_true < threshold
    mask_danger = mask_region & (r < 0)
    
    total_region = np.sum(mask_region)
    dangerous_count = np.sum(mask_danger)
    
    if dangerous_count == 0 or total_region == 0:
        return 0.0
    
    avg_magnitude = np.mean(-r[mask_danger])
    
    frequency_ratio = dangerous_count / total_region
    
    return frequency_ratio * avg_magnitude

# %%
threshold = 5

print(f"\nCatastrophic Risk Index (RUL < {threshold})")
print("-" * 50)

for model_name, y_pred in models.items():
    cri = catastrophic_risk_index(y_val, y_pred, threshold)
    print(f"{model_name}: {cri:.4f}")
# Out:
# Catastrophic Risk Index (RUL < 5)
# --------------------------------------------------
# LinearRegression: 4.3192
# DecisionTree: 5.8089
# RandomForest: 3.2065
# GradientBoosting: 3.3757

# %% [markdown]
# ## Catastrophic Risk Index (RUL < 5)
#
# We defined a Catastrophic Risk Index (CRI):
#
# CRI = (frequency of overestimation in region) × (average magnitude of overestimation)
#
# Results:
#
# - Linear Regression: 4.1773
# - Decision Tree: 5.9471
# - Random Forest: 4.6594
# - Gradient Boosting: 4.2050
#
# ### Interpretation
#
# The Decision Tree exhibits the highest catastrophic risk in the extreme failure region.
#
# Linear Regression and Gradient Boosting show nearly identical CRI values,
# despite very different structural behavior:
#
# - Linear Regression: fewer but larger overestimations
# - Gradient Boosting: more frequent but smaller overestimations
#
# This suggests that model complexity improves global predictive accuracy,
# but safety tradeoffs near extreme failure are more nuanced than aggregate metrics suggest.
#
# Therefore, evaluating RUL models requires both:
#
# - Average performance metrics (MAE, risk-aware loss)
# - Region-specific catastrophic risk analysis

# %%
df.columns
# Out:
# Index(['unit', 'cycle', 'op_1', 'op_2', 'op_3', 's_1', 's_2', 's_3', 's_4',
#        's_5', 's_6', 's_7', 's_8', 's_9', 's_10', 's_11', 's_12', 's_13',
#        's_14', 's_15', 's_16', 's_17', 's_18', 's_19', 's_20', 's_21',
#        'max_cycle', 'RUL'],
#       dtype='object')

# %%
import random
# %matplotlib inline
import matplotlib.pyplot as plt
df.columns = df.columns.str.strip()
engine_ids = df['unit'].unique()
sample_engines = random.sample(list(engine_ids),3)
sensor_cols = [col for col in df.columns if col.startswith('s_')]
for engine in sample_engines:
    engine_df = df[df['unit']== engine]
    for sensor in sensor_cols:
        plt.figure()
        plt.plot(engine_df['cycle'],engine_df[sensor])
        plt.title(f'engine{engine} - {sensor}')
        plt.xlabel('cycle')
        plt.ylabel(sensor)
        plt.show()

# %%
print(df.columns)
# Out:
# Index(['unit', 'cycle', 'op_1', 'op_2', 'op_3', 's_1', 's_2', 's_3', 's_4',
#        's_5', 's_6', 's_7', 's_8', 's_9', 's_10', 's_11', 's_12', 's_13',
#        's_14', 's_15', 's_16', 's_17', 's_18', 's_19', 's_20', 's_21',
#        'max_cycle', 'RUL'],
#       dtype='object')

# %%
low_variance = df[[col for col in df.columns if col.startswith('s_')]].std()
print(low_variance.sort_values())
# Out:
# s_1     0.000000e+00
# s_10    0.000000e+00
# s_19    0.000000e+00
# s_18    0.000000e+00
# s_16    1.387812e-17
# s_5     1.776400e-15
# s_6     1.388985e-03
# s_15    3.750504e-02
# s_8     7.098548e-02
# s_13    7.191892e-02
# s_21    1.082509e-01
# s_20    1.807464e-01
# s_11    2.670874e-01
# s_2     5.000533e-01
# s_12    7.375534e-01
# s_7     8.850923e-01
# s_17    1.548763e+00
# s_3     6.131150e+00
# s_4     9.000605e+00
# s_14    1.907618e+01
# s_9     2.208288e+01
# dtype: float64

# %%
engine_df = df[df['unit']==32]
for s in ['s_9','s_14','s_4','s_3','s_17']:
    plt.figure()
    plt.plot(engine_df['cycle'],engine_df[s])
    plt.title(s)
    plt.show()

# %%
important =['s_9','s_14','s_4','s_17']
engine_df = df[df['unit']==32].copy()


for s in important:
    engine_df[s+'_rm'] = engine_df[s].rolling(10, min_periods=1).mean()

# %%
from scipy.stats import linregress

# %%
def compute_slope(series):
    x = np.arange(len(series))
    slope, _, _, _, _ = linregress(x,series)
    return slope
slopes = {}
for s in important:
    slopes[s] = compute_slope(engine_df[s].values)
print(slopes)
# Out:
# {'s_9': np.float64(0.17855766051253755), 's_14': np.float64(0.12777852025351338), 's_4': np.float64(0.09858197850647565), 's_17': np.float64(0.014738908790300358)}

# %%
def recent_slope(series, window = 30):
    series = series[-window:]
    x = np.arange(len(series))
    slope, _, _, _, _ = linregress(x,series)
    return slope
slopes = {}
for s in important:
    slopes[s] = recent_slope(engine_df[s].values)
print(slopes)
# Out:
# {'s_9': np.float64(0.7397775305895369), 's_14': np.float64(0.39330144605117506), 's_4': np.float64(0.4220956618464949), 's_17': np.float64(0.05050055617352613)}

# %%
import pandas as pd


def add_rolling_features(df, sensor_cols, window_size=5, id_col="unit", time_col="cycle"):
   
    """
    Adds rolling mean and std for given sensor columns.
    
    Args:
        df: pandas DataFrame
        sensor_cols: list of sensor column names
        window_size: int
        
    Returns:
        df with new features
    """
    
    df = df.copy()
    
    df = df.sort_values(by=[id_col, time_col])
    
    for col in sensor_cols:
        df[f"{col}_roll_mean"] = (
            df.groupby(id_col)[col]
              .rolling(window=window_size, min_periods=1)
              .mean()
              .reset_index(level=0, drop=True)
        )
        
        df[f"{col}_roll_std"] = (
            df.groupby(id_col)[col]
              .rolling(window=window_size, min_periods=1)
              .std()
              .reset_index(level=0, drop=True)
              .fillna(0)
        )
    
    return df
sensor_cols =  ["s_12","s_7","s_14","s_20","s_21"]
df_features = add_rolling_features(df, sensor_cols, window_size=5)

# %%
from sklearn.model_selection import train_test_split
engine_ids = df_features['unit'].unique()
train_engine_ids , val_engine_ids = train_test_split(engine_ids,random_state=42,test_size=0.2)
train_set_df = df_features[df_features['unit'].isin(train_engine_ids)]
val_set_df = df_features[df_features['unit'].isin(val_engine_ids)]

# %%
train_set_df
# Out:
#        unit  cycle    op_1    op_2   op_3     s_1     s_2      s_3      s_4  \
# 192       2      1 -0.0018  0.0006  100.0  518.67  641.89  1583.84  1391.28
# 193       2      2  0.0043 -0.0003  100.0  518.67  641.82  1587.05  1393.13
# 194       2      3  0.0018  0.0003  100.0  518.67  641.55  1588.32  1398.96
# 195       2      4  0.0035 -0.0004  100.0  518.67  641.68  1584.15  1396.08
# 196       2      5  0.0005  0.0004  100.0  518.67  641.73  1579.03  1402.52
# ...     ...    ...     ...     ...    ...     ...     ...      ...      ...
# 20626   100    196 -0.0004 -0.0003  100.0  518.67  643.49  1597.98  1428.63
# 20627   100    197 -0.0016 -0.0005  100.0  518.67  643.54  1604.50  1433.58
# 20628   100    198  0.0004  0.0000  100.0  518.67  643.42  1602.46  1428.18
# 20629   100    199 -0.0011  0.0003  100.0  518.67  643.23  1605.26  1426.53
# 20630   100    200 -0.0032 -0.0005  100.0  518.67  643.85  1600.38  1432.14
#
# ...

# %%
selected_sensors = ['s_7', 's_12', 's_14', 's_20', 's_21']

features_roll = (
    selected_sensors +
    [f"{s}_roll_mean" for s in selected_sensors] +
    [f"{s}_roll_std" for s in selected_sensors]
)

X_train_roll = train_set_df[features_roll]
y_train_roll = train_set_df["RUL"]

X_val_roll = val_set_df[features_roll]
y_val_roll = val_set_df["RUL"]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_roll = scaler.fit_transform(X_train_roll)
X_val_roll = scaler.transform(X_val_roll)

# %%
from sklearn.ensemble import RandomForestRegressor
rand_for_model = RandomForestRegressor(max_depth=None,n_estimators=100,random_state=42)
rand_for_model.fit(X_train_roll,y_train_roll)
y_preds_fr = rand_for_model.predict(X_val_roll)
mae = mean_absolute_error(y_val_roll, y_preds_fr)
rmse = root_mean_squared_error(y_val_roll, y_preds_fr)
r2 = r2_score(y_val_roll,y_preds_fr)
cri = catastrophic_risk_index(y_val_roll,y_preds_fr,threshold)
dgr = count_dangerous_overestimates(y_val_roll,y_preds_fr,threshold=5)
print("r2:",r2)
print("MAE:", mae)
print(f"RMSE : {rmse}")
print(cri)
print(dgr)

# %%
from sklearn.ensemble import GradientBoostingRegressor
rand_for_model = GradientBoostingRegressor(n_estimators=100,random_state=42)
rand_for_model.fit(X_train_roll,y_train_roll)
y_preds_fr = rand_for_model.predict(X_val_roll)
mae = mean_absolute_error(y_val_roll, y_preds_fr)
rmse = root_mean_squared_error(y_val_roll, y_preds_fr)
r2 = r2_score(y_val_roll,y_preds_fr)
cri = catastrophic_risk_index(y_val_roll,y_preds_fr,threshold)
dgr = count_dangerous_overestimates(y_val_roll,y_preds_fr,threshold=5)
print("r2:",r2)
print("MAE:", mae)
print(f"RMSE : {rmse}")
print(cri)
print(dgr)
# Out:
# r2: 0.8184730755221683
# MAE: 14.816274869557407
# RMSE : 19.94270675101473
# 3.1168820993696067
# 85

# %% [markdown]
# ## Uncertainty Estimation with Random Forest
#
# A simple way to add prediction uncertainty is to look at how much the individual trees disagree. Higher spread across trees usually means the model is less certain about that RUL estimate.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

rf_uncertainty_model = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)
rf_uncertainty_model.fit(X_train_roll, y_train_roll)

tree_predictions = np.column_stack([
    tree.predict(X_val_roll) for tree in rf_uncertainty_model.estimators_
])

pred_mean = tree_predictions.mean(axis=1)
pred_std = tree_predictions.std(axis=1)
lower_90 = pred_mean - 1.64 * pred_std
upper_90 = pred_mean + 1.64 * pred_std

uncertainty_df = pd.DataFrame({
    "actual_rul": y_val_roll.values,
    "predicted_rul": pred_mean,
    "uncertainty_std": pred_std,
    "lower_90": lower_90,
    "upper_90": upper_90,
    "abs_error": np.abs(y_val_roll.values - pred_mean)
})

coverage_90 = ((uncertainty_df["actual_rul"] >= uncertainty_df["lower_90"]) &
               (uncertainty_df["actual_rul"] <= uncertainty_df["upper_90"])).mean()
corr_uncertainty_error = uncertainty_df["uncertainty_std"].corr(uncertainty_df["abs_error"])

print(f"Average uncertainty (std): {uncertainty_df['uncertainty_std'].mean():.2f}")
print(f"90% interval coverage: {coverage_90:.3f}")
print(f"Correlation between uncertainty and absolute error: {corr_uncertainty_error:.3f}")

display(uncertainty_df.sort_values("uncertainty_std", ascending=False).head(10))

plt.figure(figsize=(8, 5))
plt.scatter(uncertainty_df["uncertainty_std"], uncertainty_df["abs_error"], alpha=0.35)
plt.xlabel("Predictive uncertainty (std across trees)")
plt.ylabel("Absolute error")
plt.title("Does higher uncertainty align with higher error?")
plt.grid(alpha=0.3)
plt.show()
# Out:
# Average uncertainty (std): 19.34
# 90% interval coverage: 0.937
# Correlation between uncertainty and absolute error: 0.585
#       actual_rul  predicted_rul  uncertainty_std   lower_90    upper_90  \
# 3978          91         81.400        41.746377  12.935942  149.864058
# 3755         140         91.135        41.556910  22.981667  159.288333
# 3979          90         75.405        41.112784   7.980035  142.829965
# 1121          68         84.845        40.640263  18.194969  151.495031
# 1377          46         91.130        40.300783  25.036716  157.223284
# 1451         140         89.475        40.244992  23.473213  155.476787
# 3751         140         97.255        40.166155  31.382506  163.127494
# 1466         140         94.730        39.983961  29.156305  160.303695
# 890          131        100.225        39.954904  34.698957  165.751043
# 2372          39         85.865        39.843654  20.521407  151.208593
#
#       abs_error
# 3978      9.600
# 3755     48.865
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# -----------------------------
# 1. Extra columns for analysis
# -----------------------------
analysis_df = uncertainty_df.copy()

# signed error:
# positive => actual > predicted => underestimation
# negative => predicted > actual => overestimation
analysis_df["signed_error"] = analysis_df["actual_rul"] - analysis_df["predicted_rul"]

# overestimate amount:
# positive means model predicted more life left than reality
analysis_df["overestimate"] = analysis_df["predicted_rul"] - analysis_df["actual_rul"]

# choose what counts as a dangerous overestimate
DANGEROUS_THRESHOLD = 15
analysis_df["dangerous_overestimate"] = analysis_df["overestimate"] > DANGEROUS_THRESHOLD

print("Total samples:", len(analysis_df))
print("Dangerous overestimates:", analysis_df["dangerous_overestimate"].sum())
print("Dangerous overestimate rate:", analysis_df["dangerous_overestimate"].mean().round(3))
# Out:
# Total samples: 4070
# Dangerous overestimates: 717
# Dangerous overestimate rate: 0.176

# %%
# ------------------------------------------
# 2. Bucket uncertainty and study error trend
# ------------------------------------------
n_bins = 6

analysis_df["uncertainty_bin"] = pd.qcut(
    analysis_df["uncertainty_std"],
    q=n_bins,
    duplicates="drop"
)

bin_summary = (
    analysis_df
    .groupby("uncertainty_bin", observed=False)
    .agg(
        count=("abs_error", "size"),
        mean_uncertainty=("uncertainty_std", "mean"),
        mean_abs_error=("abs_error", "mean"),
        median_abs_error=("abs_error", "median"),
        dangerous_rate=("dangerous_overestimate", "mean"),
        mean_overestimate=("overestimate", "mean")
    )
    .reset_index()
)

display(bin_summary)

plt.figure(figsize=(8, 5))
plt.plot(bin_summary["mean_uncertainty"], bin_summary["mean_abs_error"], marker="o")
plt.xlabel("Mean uncertainty in bin")
plt.ylabel("Mean absolute error")
plt.title("Does error increase across uncertainty bins?")
plt.grid(alpha=0.3)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(bin_summary["mean_uncertainty"], bin_summary["dangerous_rate"], marker="o")
plt.xlabel("Mean uncertainty in bin")
plt.ylabel("Dangerous overestimate rate")
plt.title("Do dangerous overestimates increase with uncertainty?")
plt.grid(alpha=0.3)
plt.show()
# Out:
#     uncertainty_bin  count  mean_uncertainty  mean_abs_error  \
# 0   (-0.001, 8.104]    679          5.111006        2.720692
# 1   (8.104, 14.045]    678         11.059033        7.919499
# 2  (14.045, 18.815]    678         16.426747       13.486527
# 3   (18.815, 25.09]    678         21.893020       16.997109
# 4   (25.09, 30.667]    678         27.942816       21.599403
# 5  (30.667, 41.746]    679         33.629357       27.144374
#
#    median_abs_error  dangerous_rate  mean_overestimate
# 0            1.9800        0.001473           0.038174
# 1            6.2825        0.078171          -0.289985
# 2           11.3825        0.163717          -1.618768
# 3           14.1025        0.231563           0.383791
# 4           20.0850        0.294985           1.106276
# 5           27.7750        0.287187          -4.721340

# %%
# ---------------------------------------------------
# 3. Compare top uncertainty cases vs bottom ones
# ---------------------------------------------------
high_uncert_threshold = analysis_df["uncertainty_std"].quantile(0.80)
low_uncert_threshold = analysis_df["uncertainty_std"].quantile(0.20)

high_uncert = analysis_df[analysis_df["uncertainty_std"] >= high_uncert_threshold]
low_uncert = analysis_df[analysis_df["uncertainty_std"] <= low_uncert_threshold]

comparison = pd.DataFrame({
    "group": ["Low uncertainty (bottom 20%)", "High uncertainty (top 20%)"],
    "count": [len(low_uncert), len(high_uncert)],
    "mean_uncertainty": [low_uncert["uncertainty_std"].mean(), high_uncert["uncertainty_std"].mean()],
    "mean_abs_error": [low_uncert["abs_error"].mean(), high_uncert["abs_error"].mean()],
    "median_abs_error": [low_uncert["abs_error"].median(), high_uncert["abs_error"].median()],
    "dangerous_overestimate_rate": [
        low_uncert["dangerous_overestimate"].mean(),
        high_uncert["dangerous_overestimate"].mean()
    ],
    "avg_overestimate": [
        low_uncert["overestimate"].mean(),
        high_uncert["overestimate"].mean()
    ]
})

display(comparison)
# Out:
#                           group  count  mean_uncertainty  mean_abs_error  \
# 0  Low uncertainty (bottom 20%)    814          5.703629        3.163385
# 1    High uncertainty (top 20%)    814         33.050275       26.316542
#
#    median_abs_error  dangerous_overestimate_rate  avg_overestimate
# 0            2.3175                     0.006143          0.088102
# 1           26.7275                     0.280098         -4.468557

# %%
# -------------------------------------------------------
# 4. Maintenance decision policy comparison
# -------------------------------------------------------

# Example maintenance trigger:
# replace / inspect if estimated RUL <= this threshold
MAINTENANCE_THRESHOLD = 30

# Conservative estimate using uncertainty
analysis_df["conservative_rul"] = analysis_df["predicted_rul"] - 1.64 * analysis_df["uncertainty_std"]

# Policy A: point prediction only
analysis_df["decision_point_policy"] = analysis_df["predicted_rul"] <= MAINTENANCE_THRESHOLD

# Policy B: uncertainty-aware conservative policy
analysis_df["decision_conservative_policy"] = analysis_df["conservative_rul"] <= MAINTENANCE_THRESHOLD

# %%
# Ground truth need for maintenance
analysis_df["true_need_maintenance"] = analysis_df["actual_rul"] <= MAINTENANCE_THRESHOLD

def evaluate_policy(df, decision_col, true_col="true_need_maintenance"):
    decision = df[decision_col]
    truth = df[true_col]

    tp = ((decision == True) & (truth == True)).sum()   # correct maintenance
    fp = ((decision == True) & (truth == False)).sum()  # unnecessary early maintenance
    tn = ((decision == False) & (truth == False)).sum() # correct no-maintenance
    fn = ((decision == False) & (truth == True)).sum()  # missed risky case

    out = {
        "policy": decision_col,
        "TP_correct_maintenance": tp,
        "FP_unnecessary_maintenance": fp,
        "TN_correct_no_maintenance": tn,
        "FN_missed_risky_cases": fn,
        "precision": tp / (tp + fp) if (tp + fp) > 0 else np.nan,
        "recall": tp / (tp + fn) if (tp + fn) > 0 else np.nan,
        "false_negative_rate": fn / (fn + tp) if (fn + tp) > 0 else np.nan,
        "false_positive_rate": fp / (fp + tn) if (fp + tn) > 0 else np.nan
    }
    return out

policy_results = pd.DataFrame([
    evaluate_policy(analysis_df, "decision_point_policy"),
    evaluate_policy(analysis_df, "decision_conservative_policy")
])

display(policy_results)
# Out:
#                          policy  TP_correct_maintenance  \
# 0         decision_point_policy                     497
# 1  decision_conservative_policy                     616
#
#    FP_unnecessary_maintenance  TN_correct_no_maintenance  \
# 0                          32                       3418
# 1                         620                       2830
#
#    FN_missed_risky_cases  precision    recall  false_negative_rate  \
# 0                    123   0.939509  0.801613             0.198387
# 1                      4   0.498382  0.993548             0.006452
#
#    false_positive_rate
# 0             0.009275
# 1             0.179710

# %%
# -------------------------------------------------------
# 5. Asymmetric risk score
# -------------------------------------------------------
COST_FP = 1   # unnecessary maintenance
COST_FN = 5   # missed risky case (more dangerous)

def risk_cost(df, decision_col, true_col="true_need_maintenance", cost_fp=1, cost_fn=5):
    decision = df[decision_col]
    truth = df[true_col]

    fp = ((decision == True) & (truth == False)).sum()
    fn = ((decision == False) & (truth == True)).sum()

    total_cost = cost_fp * fp + cost_fn * fn
    avg_cost = total_cost / len(df)

    return {
        "policy": decision_col,
        "FP_unnecessary_maintenance": fp,
        "FN_missed_risky_cases": fn,
        "total_cost": total_cost,
        "average_cost_per_sample": avg_cost
    }

risk_results = pd.DataFrame([
    risk_cost(analysis_df, "decision_point_policy", cost_fp=COST_FP, cost_fn=COST_FN),
    risk_cost(analysis_df, "decision_conservative_policy", cost_fp=COST_FP, cost_fn=COST_FN)
])

display(risk_results)
# Out:
#                          policy  FP_unnecessary_maintenance  \
# 0         decision_point_policy                          32
# 1  decision_conservative_policy                         620
#
#    FN_missed_risky_cases  total_cost  average_cost_per_sample
# 0                    123         647                 0.158968
# 1                      4         640                 0.157248

# %%
# -------------------------------------------------------
# 6. Sweep maintenance thresholds
# -------------------------------------------------------
thresholds = range(10, 61, 5)

sweep_results = []

for thr in thresholds:
    temp = analysis_df.copy()

    temp["true_need_maintenance"] = temp["actual_rul"] <= thr
    temp["decision_point_policy"] = temp["predicted_rul"] <= thr
    temp["decision_conservative_policy"] = temp["conservative_rul"] <= thr

    point_cost = risk_cost(temp, "decision_point_policy", cost_fp=COST_FP, cost_fn=COST_FN)
    cons_cost = risk_cost(temp, "decision_conservative_policy", cost_fp=COST_FP, cost_fn=COST_FN)

    point_eval = evaluate_policy(temp, "decision_point_policy")
    cons_eval = evaluate_policy(temp, "decision_conservative_policy")

    sweep_results.append({
        "threshold": thr,
        "point_avg_cost": point_cost["average_cost_per_sample"],
        "cons_avg_cost": cons_cost["average_cost_per_sample"],
        "point_fn_rate": point_eval["false_negative_rate"],
        "cons_fn_rate": cons_eval["false_negative_rate"],
        "point_fp_rate": point_eval["false_positive_rate"],
        "cons_fp_rate": cons_eval["false_positive_rate"]
    })

sweep_df = pd.DataFrame(sweep_results)
display(sweep_df)
# Out:
#     threshold  point_avg_cost  cons_avg_cost  point_fn_rate  cons_fn_rate  \
# 0          10        0.073464       0.056265       0.263636      0.000000
# 1          15        0.090909       0.093857       0.218750      0.000000
# 2          20        0.098280       0.122359       0.180952      0.000000
# 3          25        0.134889       0.143735       0.203846      0.000000
# 4          30        0.158968       0.157248       0.198387      0.006452
# 5          35        0.158231       0.173710       0.165278      0.015278
# 6          40        0.169042       0.177641       0.154878      0.008537
# 7          45        0.205160       0.193857       0.167391      0.007609
# 8          50        0.237346       0.215971       0.175490      0.014706
# 9          55        0.258968       0.240541       0.174107      0.020536
# 10         60        0.288206       0.257002       0.174590      0.018852
#
#     point_fp_rate  cons_fp_rate
# 0        0.002338      0.059481
# ...

# %%
plt.figure(figsize=(8, 5))
plt.plot(sweep_df["threshold"], sweep_df["point_avg_cost"], marker="o", label="Point prediction policy")
plt.plot(sweep_df["threshold"], sweep_df["cons_avg_cost"], marker="o", label="Uncertainty-aware policy")
plt.xlabel("Maintenance threshold")
plt.ylabel("Average asymmetric cost")
plt.title("Policy comparison across maintenance thresholds")
plt.grid(alpha=0.3)
plt.legend()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(sweep_df["threshold"], sweep_df["point_fn_rate"], marker="o", label="Point policy FN rate")
plt.plot(sweep_df["threshold"], sweep_df["cons_fn_rate"], marker="o", label="Uncertainty-aware FN rate")
plt.xlabel("Maintenance threshold")
plt.ylabel("False negative rate")
plt.title("Missed risky cases across thresholds")
plt.grid(alpha=0.3)
plt.legend()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(sweep_df["threshold"], sweep_df["point_fp_rate"], marker="o", label="Point policy FP rate")
plt.plot(sweep_df["threshold"], sweep_df["cons_fp_rate"], marker="o", label="Uncertainty-aware FP rate")
plt.xlabel("Maintenance threshold")
plt.ylabel("False positive rate")
plt.title("Unnecessary maintenance across thresholds")
plt.grid(alpha=0.3)
plt.legend()
plt.show()

# %%
# -------------------------------------------------------
# 7. Optional hybrid policy
# -------------------------------------------------------
UNCERTAINTY_THRESHOLD = analysis_df["uncertainty_std"].quantile(0.80)

analysis_df["decision_hybrid_policy"] = (
    (analysis_df["predicted_rul"] <= MAINTENANCE_THRESHOLD) |
    (analysis_df["uncertainty_std"] >= UNCERTAINTY_THRESHOLD)
)

hybrid_eval = pd.DataFrame([
    evaluate_policy(analysis_df, "decision_point_policy"),
    evaluate_policy(analysis_df, "decision_conservative_policy"),
    evaluate_policy(analysis_df, "decision_hybrid_policy")
])

hybrid_risk = pd.DataFrame([
    risk_cost(analysis_df, "decision_point_policy", cost_fp=COST_FP, cost_fn=COST_FN),
    risk_cost(analysis_df, "decision_conservative_policy", cost_fp=COST_FP, cost_fn=COST_FN),
    risk_cost(analysis_df, "decision_hybrid_policy", cost_fp=COST_FP, cost_fn=COST_FN)
])

display(hybrid_eval)
display(hybrid_risk)
# Out:
#                          policy  TP_correct_maintenance  \
# 0         decision_point_policy                     497
# 1  decision_conservative_policy                     616
# 2        decision_hybrid_policy                     498
#
#    FP_unnecessary_maintenance  TN_correct_no_maintenance  \
# 0                          32                       3418
# 1                         620                       2830
# 2                         845                       2605
#
#    FN_missed_risky_cases  precision    recall  false_negative_rate  \
# 0                    123   0.939509  0.801613             0.198387
# 1                      4   0.498382  0.993548             0.006452
# 2                    122   0.370812  0.803226             0.196774
#
#    false_positive_rate
# 0             0.009275
# 1             0.179710
# 2             0.244928
#                          policy  FP_unnecessary_maintenance  \
# 0         decision_point_policy                          32
# ...

# %%
results_df = val_set_df[['unit', 'cycle', 'RUL']].copy().reset_index(drop=True)

results_df["pred_mean"] = pred_mean
results_df["pred_std"] = pred_std

results_df["error"] = results_df["RUL"] - results_df["pred_mean"]
results_df["abs_error"] = np.abs(results_df["error"])

print(results_df.head())
# Out:
#    unit  cycle  RUL  pred_mean   pred_std   error  abs_error
# 0     1      1  140    129.000  17.787355  11.000     11.000
# 1     1      2  140    121.305  23.278359  18.695     18.695
# 2     1      3  140    133.575  13.218713   6.425      6.425
# 3     1      4  140    133.160  12.567991   6.840      6.840
# 4     1      5  140    133.860  13.717886   6.140      6.140

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# -----------------------------
# 1. Define policies
# -----------------------------

def evaluate_policy(y_true, y_pred_decision, risky_threshold, c_fp=1, c_fn=10):
    """
    y_true: actual RUL
    y_pred_decision: True = maintain, False = don't maintain
    risky_threshold: actual RUL <= threshold means risky
    c_fp: cost of unnecessary maintenance
    c_fn: cost of missing risky case
    """

    actual_risky = y_true <= risky_threshold
    maintain = y_pred_decision

    false_negative = actual_risky & (~maintain)   # dangerous miss
    false_positive = (~actual_risky) & maintain   # unnecessary maintenance

    fn_count = false_negative.sum()
    fp_count = false_positive.sum()

    fn_rate = fn_count / actual_risky.sum() if actual_risky.sum() > 0 else 0
    fp_rate = fp_count / (~actual_risky).sum() if (~actual_risky).sum() > 0 else 0

    total_cost = (fn_count * c_fn + fp_count * c_fp) / len(y_true)

    return {
        "fn_count": fn_count,
        "fp_count": fp_count,
        "fn_rate": fn_rate,
        "fp_rate": fp_rate,
        "cost": total_cost
    }


# -----------------------------
# 2. Threshold sweep
# -----------------------------

thresholds = [10, 15, 20, 25, 30, 40, 50, 60]
k = 1.64   # 90% conservative interval factor

threshold_results = []

for threshold in thresholds:
    y_true = results_df["RUL"].values
    pred_mean = results_df["pred_mean"].values
    pred_std = results_df["pred_std"].values

    # Policy 1: point prediction only
    point_maintain = pred_mean <= threshold

    # Policy 2: uncertainty-aware conservative prediction
    conservative_pred = pred_mean - k * pred_std
    uncertainty_maintain = conservative_pred <= threshold

    point_metrics = evaluate_policy(
        y_true,
        point_maintain,
        risky_threshold=threshold,
        c_fp=1,
        c_fn=10
    )

    uncertainty_metrics = evaluate_policy(
        y_true,
        uncertainty_maintain,
        risky_threshold=threshold,
        c_fp=1,
        c_fn=10
    )

    threshold_results.append({
        "threshold": threshold,
        "policy": "Point Prediction",
        **point_metrics
    })

    threshold_results.append({
        "threshold": threshold,
        "policy": "Uncertainty-Aware",
        **uncertainty_metrics
    })

threshold_df = pd.DataFrame(threshold_results)
threshold_df
# Out:
#     threshold             policy  fn_count  fp_count   fn_rate   fp_rate  \
# 0          10   Point Prediction        58         9  0.263636  0.002338
# 1          10  Uncertainty-Aware         0       229  0.000000  0.059481
# 2          15   Point Prediction        70        20  0.218750  0.005333
# 3          15  Uncertainty-Aware         0       382  0.000000  0.101867
# 4          20   Point Prediction        76        20  0.180952  0.005479
# 5          20  Uncertainty-Aware         0       498  0.000000  0.136438
# 6          25   Point Prediction       106        19  0.203846  0.005352
# 7          25  Uncertainty-Aware         0       585  0.000000  0.164789
# 8          30   Point Prediction       123        32  0.198387  0.009275
# 9          30  Uncertainty-Aware         4       620  0.006452  0.179710
# 10         40   Point Prediction       127        53  0.154878  0.016308
# 11         40  Uncertainty-Aware         7       688  0.008537  0.211692
# ...

# %%
plt.figure(figsize=(8, 5))

for policy in threshold_df["policy"].unique():
    temp = threshold_df[threshold_df["policy"] == policy]
    plt.plot(temp["threshold"], temp["cost"], marker="o", label=policy)

plt.xlabel("Maintenance Threshold")
plt.ylabel("Asymmetric Cost")
plt.title("Cost vs Maintenance Threshold")
plt.legend()
plt.grid(True)
plt.show()

# %%
# -----------------------------
# 3. Cost ratio sensitivity
# -----------------------------

cost_ratios = [5, 10, 20, 50, 100]
fixed_threshold = 20
k = 1.64

cost_ratio_results = []

for c_fn in cost_ratios:
    y_true = results_df["RUL"].values
    pred_mean = results_df["pred_mean"].values
    pred_std = results_df["pred_std"].values

    point_maintain = pred_mean <= fixed_threshold

    conservative_pred = pred_mean - k * pred_std
    uncertainty_maintain = conservative_pred <= fixed_threshold

    point_metrics = evaluate_policy(
        y_true,
        point_maintain,
        risky_threshold=fixed_threshold,
        c_fp=1,
        c_fn=c_fn
    )

    uncertainty_metrics = evaluate_policy(
        y_true,
        uncertainty_maintain,
        risky_threshold=fixed_threshold,
        c_fp=1,
        c_fn=c_fn
    )

    cost_ratio_results.append({
        "failure_cost": c_fn,
        "policy": "Point Prediction",
        **point_metrics
    })

    cost_ratio_results.append({
        "failure_cost": c_fn,
        "policy": "Uncertainty-Aware",
        **uncertainty_metrics
    })

cost_ratio_df = pd.DataFrame(cost_ratio_results)
cost_ratio_df
# Out:
#    failure_cost             policy  fn_count  fp_count   fn_rate   fp_rate  \
# 0             5   Point Prediction        76        20  0.180952  0.005479
# 1             5  Uncertainty-Aware         0       498  0.000000  0.136438
# 2            10   Point Prediction        76        20  0.180952  0.005479
# 3            10  Uncertainty-Aware         0       498  0.000000  0.136438
# 4            20   Point Prediction        76        20  0.180952  0.005479
# 5            20  Uncertainty-Aware         0       498  0.000000  0.136438
# 6            50   Point Prediction        76        20  0.180952  0.005479
# 7            50  Uncertainty-Aware         0       498  0.000000  0.136438
# 8           100   Point Prediction        76        20  0.180952  0.005479
# 9           100  Uncertainty-Aware         0       498  0.000000  0.136438
#
#        cost
# 0  0.098280
# 1  0.122359
# 2  0.191646
# 3  0.122359
# 4  0.378378
# 5  0.122359
# 6  0.938575
# 7  0.122359
# 8  1.872236
# ...

# %%
plt.figure(figsize=(8, 5))

for policy in cost_ratio_df["policy"].unique():
    temp = cost_ratio_df[cost_ratio_df["policy"] == policy]
    plt.plot(temp["failure_cost"], temp["cost"], marker="o", label=policy)

plt.xlabel("Failure Cost")
plt.ylabel("Asymmetric Cost")
plt.title(f"Cost Sensitivity at Threshold = {fixed_threshold}")
plt.legend()
plt.grid(True)
plt.show()

# %%
threshold_df.to_csv("threshold_sensitivity_results.csv", index=False)
cost_ratio_df.to_csv("cost_ratio_sensitivity_results.csv", index=False)

print("Saved threshold_sensitivity_results.csv")
print("Saved cost_ratio_sensitivity_results.csv")
# Out:
# Saved threshold_sensitivity_results.csv
# Saved cost_ratio_sensitivity_results.csv

# %% [markdown]
# 1. Uncertainty strongly aligns with prediction error and risk
# 2. Uncertainty-aware policies eliminate most dangerous failures
# 3. Trade-off: increased maintenance vs reduced risk
# 4. Policy outperforms baseline across all thresholds
# 5. Policy remains stable under increasing failure cost

# %%
threshold_df.sort_values("cost")
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))

for policy in threshold_df["policy"].unique():
    temp = threshold_df[threshold_df["policy"] == policy]
    plt.plot(temp["fp_rate"], temp["fn_rate"], marker="o", label=policy)

plt.xlabel("False Positive Rate")
plt.ylabel("False Negative Rate")
plt.title("Safety vs Maintenance Trade-off")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 1. Uncertainty strongly reduces false negatives (dangerous failures)
# 2. This comes at the cost of increased false positives (extra maintenance)
# 3. Under asymmetric cost, this trade-off is favorable
# 4. Uncertainty effectively acts as a risk indicator
